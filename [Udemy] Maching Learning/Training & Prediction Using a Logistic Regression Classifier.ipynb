# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('housing.csv')
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5950     -117.87     34.14                30.0       2495.0           586.0
# 18689    -121.75     36.96                19.0       3461.0           634.0
# 8977     -118.42     34.01                42.0       1700.0           438.0
# 2720     -115.52     32.77                18.0       1715.0           337.0
# 12572    -121.41     38.53                35.0       2061.0           371.0
#
#        population  households  median_income  median_house_value  \
# 5950       1139.0       559.0         2.9375            209200.0
# 18689      2790.0       607.0         4.7569            190800.0
# 8977        997.0       436.0         2.9213            305000.0
# 2720       1166.0       333.0         2.2417             79200.0
# 12572      1110.0       342.0         3.1944             79000.0
#
#       ocean_proximity
# 5950           INLAND
# 18689       <1H OCEAN
# 8977        <1H OCEAN
# 2720           INLAND
# 12572          INLAND

# %%
housing_data = housing_data.dropna()
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data = pd.get_dummies(housing_data, columns=["ocean_proximity"])
housing_data.shape
# Out:
# (19475, 14)

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14344    -117.17     32.73                52.0         55.0            18.0
# 10875    -117.89     33.72                23.0       2305.0           538.0
# 10494    -117.69     33.47                13.0       2020.0           378.0
# 4712     -118.36     34.06                39.0       2810.0           670.0
# 8525     -118.33     33.89                39.0       1880.0           361.0
#
#        population  households  median_income  median_house_value  \
# 14344        65.0        22.0         1.6591            112500.0
# 10875      2493.0       502.0         3.6618            183500.0
# 10494       679.0       290.0         5.7560            305600.0
# 4712       1109.0       624.0         3.2500            355000.0
# 8525        982.0       357.0         4.1953            226900.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 14344                          0                       0
# 10875                          1                       0
# 10494                          1                       0
# 4712                           1                       0
# 8525                           1                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 14344                       0                         0
# 10875                       0                         0
# 10494                       0                         0
# 4712                        0                         0
# 8525                        0                         0
#
#        ocean_proximity_NEAR OCEAN
# 14344                           1
# 10875                           0
# 10494                           0
# 4712                            0
# 8525                            0

# %%
median = housing_data['median_house_value'].median()
median
# Out:
# 173800.0

# %%
housing_data['above_median'] = (housing_data['median_house_value'] - median) > 0
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12260    -116.96     33.79                21.0       2990.0           691.0
# 19957    -119.32     36.22                 5.0       2319.0           438.0
# 4214     -118.27     34.13                47.0       1375.0           359.0
# 13835    -117.20     34.52                12.0       4476.0           761.0
# 15781    -122.41     37.77                52.0       1963.0           565.0
#
#        population  households  median_income  median_house_value  \
# 12260      2108.0       660.0         2.0135             83000.0
# 19957      1283.0       423.0         3.6343             95400.0
# 4214       1512.0       418.0         2.1071            208900.0
# 13835      2255.0       735.0         3.9250            118500.0
# 15781      1628.0       524.0         2.6083            193800.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 12260                          0                       1
# 19957                          0                       1
# 4214                           1                       0
# 13835                          0                       1
# 15781                          0                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 12260                       0                         0
# 19957                       0                         0
# 4214                        0                         0
# 13835                       0                         0
# 15781                       0                         1
#
#        ocean_proximity_NEAR OCEAN  above_median
# 12260                           0         False
# 19957                           0         False
# 4214                            0          True
# 13835                           0         False
# 15781                           0          True

# %%
X = housing_data.drop(['median_house_value', 'above_median'], axis=1)
Y = housing_data['above_median']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(solver='liblinear').fit(x_train, y_train)

# %%
y_pred = logistic_model.predict(x_test)

# %%
df_pred_actual = pd.DataFrame({'predicted':y_pred, 'actual':y_test})
df_pred_actual.head(10)
# Out:
#        predicted  actual
# 12640      False   False
# 9524        True    True
# 13467      False   False
# 19588      False    True
# 7216       False   False
# 13798      False   False
# 13977      False   False
# 11655       True    True
# 11800      False   False
# 19341      False   False
