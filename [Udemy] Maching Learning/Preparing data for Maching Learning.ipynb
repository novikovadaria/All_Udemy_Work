# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('housing.csv')
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12512    -121.45     38.55                19.0       3374.0           808.0
# 13572    -117.28     34.14                40.0       2190.0           496.0
# 8061     -118.20     33.84                35.0       3405.0           779.0
# 17545    -121.87     37.34                52.0       1087.0           166.0
# 8274     -118.17     33.77                25.0       4405.0          1262.0
#
#        population  households  median_income  median_house_value  \
# 12512      1412.0       753.0         1.4889             77600.0
# 13572      1214.0       493.0         2.3947             81900.0
# 8061       1953.0       671.0         2.7813            159200.0
# 17545       650.0       194.0         6.6345            309000.0
# 8274       2178.0      1090.0         3.0503            225000.0
#
#       ocean_proximity
# 12512          INLAND
# 13572          INLAND
# 8061       NEAR OCEAN
# 17545       <1H OCEAN
# 8274       NEAR OCEAN

# %%
housing_data = housing_data.dropna()
housing_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
# housing_data = pd.get_dummies(housing_data, columns=["ocean_proximity"])

# %%
housing_data.shape
# Out:
# (19475, 14)

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19358    -123.02     38.81                45.0       1717.0           389.0
# 5588     -118.30     33.79                35.0       2793.0           686.0
# 20       -122.27     37.85                40.0        751.0           184.0
# 19909    -119.30     36.33                44.0       2060.0           414.0
# 15657    -122.41     37.79                52.0       6016.0          2509.0
#
#        population  households  median_income  median_house_value  \
# 19358       916.0       367.0         3.2425            138800.0
# 5588       2255.0       682.0         3.0057            235300.0
# 20          409.0       166.0         1.3578            147500.0
# 19909       819.0       355.0         2.8795             77000.0
# 15657      3436.0      2119.0         2.5166            275000.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 19358                          1                       0
# 5588                           1                       0
# 20                             0                       0
# 19909                          0                       1
# 15657                          0                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 19358                       0                         0
# 5588                        0                         0
# 20                          0                         1
# 19909                       0                         0
# 15657                       0                         1
#
#        ocean_proximity_NEAR OCEAN
# 19358                           0
# 5588                            0
# 20                              0
# 19909                           0
# 15657                           0

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                          0                       0                       0
# 1                          0                       0                       0
# 2                          0                       0                       0
# 3                          0                       0                       0
# 4                          0                       0                       0
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0                         1                           0
# 1                         1                           0
# 2                         1                           0
# 3                         1                           0
# 4                         1                           0

# %%
X = housing_data.drop('median_house_value', axis=1)
Y = housing_data['median_house_value']

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))
